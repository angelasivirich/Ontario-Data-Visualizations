# %%
import pandas as pd

# File to Load 
covid = "Resources/covid_cases.csv"
death_registry = "Resources/death_registry.csv"
marriage_license = "Resources/marriage_license.csv"


# Read School and Student Data File and store into Pandas DataFrames
covid_data = pd.read_csv(covid)
death_registry_data = pd.read_csv(death_registry)
marriage_license_data = pd.read_csv(marriage_license)

# Combine the data into a single dataset.  
#school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
covid_data.head()
# Out:
#       _id  Assigned_ID Outbreak Associated       Age Group  \
# 0  801426            1            Sporadic  50 to 59 Years
# 1  801427            2            Sporadic  50 to 59 Years
# 2  801428            3            Sporadic  20 to 29 Years
# 3  801429            4            Sporadic  60 to 69 Years
# 4  801430            5            Sporadic  60 to 69 Years
#
#       Neighbourhood Name  FSA Source of Infection Classification Episode Date  \
# 0        Willowdale East  M2N              Travel      CONFIRMED   2020-01-22
# 1        Willowdale East  M2N              Travel      CONFIRMED   2020-01-21
# 2      Parkwoods-Donalda  M3A              Travel      CONFIRMED   2020-02-05
# 3  Church-Yonge Corridor  M4W              Travel      CONFIRMED   2020-02-16
# 4  Church-Yonge Corridor  M4W              Travel      CONFIRMED   2020-02-20
#
#   Reported Date Client Gender   Outcome Currently Hospitalized  \
# 0    2020-01-23        FEMALE  RESOLVED                     No
# ...

# %%
death_registry_data
# Out:
#        _id CIVIC_CENTRE  DEATH_LICENSES       PLACE_OF_DEATH TIME_PERIOD
# 0    13724           ET              69  Outside City Limits      Jan-11
# 1    13725           ET             341              Toronto      Jan-11
# 2    13726           NY             141  Outside City Limits      Jan-11
# 3    13727           NY             540              Toronto      Jan-11
# 4    13728           SC             129  Outside City Limits      Jan-11
# ..     ...          ...             ...                  ...         ...
# 740  14464           ET             171  Outside City Limits      Dec-20
# 741  14465           ET             833              Toronto      Dec-20
# 742  14466           SC               3              Toronto      Dec-20
# 743  14467           TO               1  Outside City Limits      Dec-20
# 744  14468           TO              16              Toronto      Dec-20
#
# [745 rows x 5 columns]

# %%
marriage_license_data
# Out:
#       _id CIVIC_CENTRE  MARRIAGE_LICENSES TIME_PERIOD
# 0    8354           ET                 80      Jan-11
# 1    8355           NY                136      Jan-11
# 2    8356           SC                159      Jan-11
# 3    8357           TO                367      Jan-11
# 4    8358           ET                109      Feb-11
# ..    ...          ...                ...         ...
# 456  8810           SC                581      Oct-20
# 457  8811           NY                366      Nov-20
# 458  8812           SC                320      Nov-20
# 459  8813           NY                168      Dec-20
# 460  8814           SC                200      Dec-20
#
# [461 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# %%
marriage_license_data.hist(column = "MARRIAGE_LICENSES")
plt.xlabel("TIME_PERIOD")
plt.ylabel("MARRIAGE_LICENSES")
plt.show()
